# %%
# 強化学習環境の標準ライブラリ
# !pip install gymnasium
# ゲーム画面のレンダリング及び演算に使用するライブラリ
# !pip install pygame numpy
# Out:
# Requirement already satisfied: gymnasium in c:\venv_for_ipynb\venv_python_3.11\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\venv_for_ipynb\venv_python_3.11\lib\site-packages (from gymnasium) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\venv_for_ipynb\venv_python_3.11\lib\site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\venv_for_ipynb\venv_python_3.11\lib\site-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\venv_for_ipynb\venv_python_3.11\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: pygame in c:\venv_for_ipynb\venv_python_3.11\lib\site-packages (2.6.1)
# Requirement already satisfied: numpy in c:\venv_for_ipynb\venv_python_3.11\lib\site-packages (2.2.6)

# %%
import numpy as np
import pandas as pd
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback, CallbackList

class TrainingRewardLogger(BaseCallback):
    """
    エピソードが終了するたびに（現在のtimesteps、episode_reward）を記録。
    Monitorラッパーがinfo['episode']を挿入してくれるので、それを活用。
    """
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.t = []
        self.rew = []

    def _on_step(self) -> bool:
        # VecEnv基準でinfosはリスト。done時に'episode'キーが含まれる。
        infos = self.locals.get("infos", None)
        if infos:
            for info in infos:
                ep = info.get("episode")
                if ep is not None:  # エピソード終了時点
                    self.t.append(self.num_timesteps)
                    self.rew.append(ep["r"])
        return True

class EvalWithAccuracy(EvalCallback):
    """
    基本的なEvalCallbackを拡張し、「eval/accuracy_pct」をTensorBoardに記録し、
    (timesteps, accuracy_pct) をhistoryとして保管。
    正解率 = 各エピソードの (game_score / max_score)*100 の平均。
    """
    def __init__(self, eval_env, *args, n_eval_episodes=5, **kwargs):
        super().__init__(eval_env, *args, n_eval_episodes=n_eval_episodes, **kwargs)
        self.eval_steps = []
        self.eval_acc = []

    def _on_step(self) -> bool:
        result = super()._on_step()

        if self.eval_freq > 0 and (self.n_calls % self.eval_freq == 0):
            acc_list = []
            for _ in range(self.n_eval_episodes):
                # Gymnasium/VecEnvのresetと互換
                try:
                    obs, _ = self.eval_env.reset()
                except Exception:
                    obs = self.eval_env.reset()

                dones = np.array([False])
                while not dones[0]:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, rewards, dones, infos = self.eval_env.step(action)

                info = infos[0] if isinstance(infos, (list, tuple)) else infos
                gs = info.get("game_score", None)
                ms = info.get("max_score", None)
                if gs is not None and ms and ms > 0:
                    acc_list.append(100.0 * float(gs) / float(ms))

            if acc_list:
                mean_acc = float(np.mean(acc_list))
                # TensorBoardに記録
                self.logger.record("eval/accuracy_pct", mean_acc)
                # 内部記録（グラフ用）
                self.eval_steps.append(self.n_calls)  # または self.num_timesteps
                self.eval_acc.append(mean_acc)
        return result
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
import gymnasium as gym
from gymnasium import spaces
import pygame
import numpy as np

class RhythmGameEnv(gym.Env):
    """
    強化学習エージェントのためのリズムゲーム環境（Gymnasium標準）。
    - 行動: 0～3 レーンを叩く、4は無入力
    - 観測: (H, W, 1) グレースケール画像(uint8)
    """
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 30}

    def __init__(self, density: str = "medium", render_mode: str | None = None):
        super().__init__()
        # ---- 環境パラメータ ----
        self.render_mode = render_mode
        self.density = density
        self.screen_width, self.screen_height = 300, 400
        self.num_lanes = 4
        self.note_width, self.note_height = 50, 20
        self.note_speed = 5                  # px/frame
        self.max_frames = 500                # エピソードの長さ（フレーム）
        self.judgment_line_y = self.screen_height - 50

        # 判定範囲/報酬
        self.judgments = {
            "perfect": {"range": 5,  "reward": 100},
            "good":    {"range": 12, "reward": 60},
            "ok":      {"range": 20, "reward": 40},
        }
        self.miss_penalty = -50              # ノーツを見逃した場合のペナルティ
        self.wrong_input_penalty = -5        # 判定ゾーンにノーツがないのに叩いた場合

        # 密度（フレーム間の最小間隔）
        self.density_settings = {"low": 15, "medium": 10, "high": 5}
        self.min_spacing_frames = self.density_settings[self.density]

        # ---- Gym空間 ----
        self.action_space = spaces.Discrete(self.num_lanes + 1)  # 0..3: 打鍵, 4: 無入力
        self.observation_space = spaces.Box(
            low=0, high=255, shape=(self.screen_height, self.screen_width, 1), dtype=np.uint8
        )

        # ---- レンダリング初期化 ----
        self.screen = None
        self.clock = None
        if self.render_mode == "human":
            pygame.init()
            pygame.display.set_caption("Rhythm Game RL Environment")
            self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
            self.clock = pygame.time.Clock()

        # ランタイム状態（resetで初期化）
        self.notes = []
        self.current_frame = 0
        self.total_reward = 0
        self.total_notes = 0
        self.hits = 0
        self.misses = 0
        self.max_score = 0

    # ---------- ユーティリティ ----------
    def _generate_notes(self):
        """シードの一貫性のためにself.np_randomを使用。"""
        notes = []
        for frame in range(0, self.max_frames, self.min_spacing_frames):
            if self.np_random.random() < 0.7:  # 70%の確率でノーツを生成
                lane = int(self.np_random.integers(0, self.num_lanes))
                # 開始位置は画面の上部外側（フレームの進行に伴い下に移動）
                y0 = -self.note_height / 2 - frame * self.note_speed
                notes.append([lane, y0])
        return notes

    def _calculate_max_score(self):
        """全てのノーツをperfectで叩いた場合の理論上の最高スコア。"""
        return len(self.notes) * self.judgments["perfect"]["reward"]

    def _draw_surface(self):
        surface = pygame.Surface((self.screen_width, self.screen_height))
        surface.fill((255, 255, 255))
        lane_w = self.screen_width / self.num_lanes
        for i in range(1, self.num_lanes):
            pygame.draw.line(surface, (200, 200, 200),
                             (i * lane_w, 0), (i * lane_w, self.screen_height), 1)
        for lane, y in self.notes:
            if 0 <= y <= self.screen_height:
                x = (lane + 0.5) * lane_w
                rect = pygame.Rect(x - self.note_width / 2, y - self.note_height / 2,
                                  self.note_width, self.note_height)
                pygame.draw.rect(surface, (0, 0, 0), rect)
        # 判定ライン（レンダリング時にのみ表示）
        pygame.draw.line(surface, (255, 0, 0), (0, self.judgment_line_y),
                         (self.screen_width, self.judgment_line_y), 2)
        return surface

    def _get_obs(self):
        surface = pygame.Surface((self.screen_width, self.screen_height))
        surface.fill((255, 255, 255))
        lane_w = self.screen_width / self.num_lanes
        for i in range(1, self.num_lanes):
            pygame.draw.line(surface, (200, 200, 200),
                             (i * lane_w, 0), (i * lane_w, self.screen_height), 1)
        for lane, y in self.notes:
            if 0 <= y <= self.screen_height:
                x = (lane + 0.5) * lane_w
                rect = pygame.Rect(x - self.note_width / 2, y - self.note_height / 2,
                                  self.note_width, self.note_height)
                pygame.draw.rect(surface, (0, 0, 0), rect)

        rgb = pygame.surfarray.array3d(surface)      # (W,H,3)
        rgb = np.transpose(rgb, (1, 0, 2))           # (H,W,3)
        gray = rgb.mean(axis=2, keepdims=True)       # float
        return gray.astype(np.uint8)                 # (H,W,1)

    def _get_info(self):
        hit_rate = (self.hits / self.total_notes) if self.total_notes > 0 else 0.0
        return {
            "total_reward": self.total_reward,
            "game_score": self.total_reward,   # 報酬と同じ値を使用（必要に応じて分離可能）
            "max_score": self.max_score,
            "hits": self.hits,
            "misses": self.misses,
            "hit_rate": hit_rate,
            "notes_left": len(self.notes),
        }

    # ---------- Gym API ----------
    def reset(self, seed: int | None = None, options=None):
        super().reset(seed=seed)
        self.current_frame = 0
        self.notes = self._generate_notes()
        self.total_notes = len(self.notes)
        self.hits = 0
        self.misses = 0
        self.total_reward = 0
        self.max_score = self._calculate_max_score()
        obs = self._get_obs()
        info = self._get_info()
        return obs, info

    def step(self, action: int):
        # 1) ノーツの移動
        for n in self.notes:
            n[1] += self.note_speed

        # 2) 入力処理（1フレームあたり最大1つのノーツのみヒット可能）
        reward = 0.0
        processed = False
        action_taken = (action < self.num_lanes)

        for note in self.notes[:]:
            lane, y = note
            diff = abs(y - self.judgment_line_y)
            if diff <= self.judgments["perfect"]["range"]:
                if action_taken and action == lane:
                    reward += self.judgments["perfect"]["reward"]
                    self.hits += 1
                    self.notes.remove(note)
                processed = True
                break
            elif diff <= self.judgments["good"]["range"]:
                if action_taken and action == lane:
                    reward += self.judgments["good"]["reward"]
                    self.hits += 1
                    self.notes.remove(note)
                processed = True
                break
            elif diff <= self.judgments["ok"]["range"]:
                if action_taken and action == lane:
                    reward += self.judgments["ok"]["reward"]
                    self.hits += 1
                    self.notes.remove(note)
                processed = True
                break

        # 3) 誤入力ペナルティ
        if action_taken and not processed:
            reward += self.wrong_input_penalty

        # 4) 見逃しノーツ（判定ラインを通過）のペナルティ
        missed = [n for n in self.notes if n[1] > self.judgment_line_y + self.judgments["ok"]["range"]]
        if missed:
            self.misses += len(missed)
            reward += self.miss_penalty * len(missed)
            self.notes = [n for n in self.notes if n not in missed]

        self.total_reward += reward
        self.current_frame += 1

        # 5) 終了判定
        terminated = (len(self.notes) == 0) or (self.current_frame >= self.max_frames)
        truncated = False  # 時間制限などで打ち切る必要がなければFalse

        obs = self._get_obs()
        info = self._get_info()

        # 6) レンダリング
        if self.render_mode == "human":
            # humanモードでは実際の画面も更新
            surf = self._draw_surface()
            self.screen.blit(surf, (0, 0))
            pygame.event.pump()
            pygame.display.flip()
            if self.clock is not None:
                self.clock.tick(self.metadata["render_fps"])

        return obs, reward, terminated, truncated, info

    def render(self):
        if self.render_mode == "rgb_array":
            # 判定ラインを含むフレームを返す
            surf = self._draw_surface()
            rgb = pygame.surfarray.array3d(surf)
            rgb = np.transpose(rgb, (1, 0, 2))
            return rgb
        elif self.render_mode == "human":
            # step()で既に更新済み
            return None

    def close(self):
        if self.screen is not None:
            pygame.quit()
            self.screen = None
            self.clock = None

# %%
# --- 環境がGymnasium標準に準拠しているか確認 ---
from gymnasium.utils.env_checker import check_env

try:
    # レンダリングなしでチェックする方が高速です。
    env_check = RhythmGameEnv(density='medium', render_mode=None)
    check_env(env_check)
    print("✅ Gymnasium環境標準チェックに合格しました！")
except Exception as e:
    print(f"❌ 環境標準チェックに失敗しました: {e}")


# --- ランダムエージェントによるゲームプレイの可視化（改善版） ---
# render_modeを'human'に設定してゲームウィンドウを表示します。
env = RhythmGameEnv(density='high', render_mode='human')
# seedを設定して、常に同じノーツパターンでテストできるようにします。
observation, info = env.reset(seed=42)

print("\n--- ランダムエージェントのテスト開始 ---")
print("エピソードが1回終了するまでゲームを実行します。Pygameウィンドウを確認してください。")

done = False
truncated = False
total_reward = 0
frame_count = 0

while not done and not truncated:
    action = env.action_space.sample()  # ランダムな行動を選択
    observation, reward, done, truncated, info = env.step(action)
    total_reward += reward
    frame_count += 1
    
    # 報酬が発生した時のみログを出力し、可読性を向上
    score = info.get('game_score', info.get('total_reward', 0.0))

    if reward != 0:
        print(f"フレーム: {frame_count}, 行動: {action}, 報酬: {reward:.1f}, 現在の合計スコア: {score:.1f}")
        
print("\n--- エピソード終了 ---")
print(f"合計フレーム: {frame_count}")
print(f"最終スコア: {score:.1f}")

env.close() # テスト終了後にウィンドウを閉じる
print("--- テスト終了 ---")
# Out:
# c:\venv_for_ipynb\venv_python_3.11\Lib\site-packages\gymnasium\utils\env_checker.py:434: UserWarning: WARN: Not able to test alternative render modes due to the environment not having a spec. Try instantiating the environment through `gymnasium.make`
#   logger.warn(
# ✅ Gymnasium環境標準チェックに合格しました！
#
# --- ランダムエージェントのテスト開始 ---
# エピソードが1回終了するまでゲームを実行します。Pygameウィンドウを確認してください。
# フレーム: 1, 行動: 2, 報酬: -5.0, 現在の合計スコア: -5.0
# フレーム: 2, 行動: 1, 報酬: -5.0, 現在の合計スコア: -10.0
# フレーム: 3, 行動: 1, 報酬: -5.0, 現在の合計スコア: -15.0
# フレーム: 4, 行動: 1, 報酬: -5.0, 現在の合計スコア: -20.0
# フレーム: 6, 行動: 3, 報酬: -5.0, 現在の合計スコア: -25.0
# フレーム: 7, 行動: 0, 報酬: -5.0, 現在の合計スコア: -30.0
# フレーム: 8, 行動: 2, 報酬: -5.0, 現在の合計スコア: -35.0
# フレーム: 9, 行動: 0, 報酬: -5.0, 現在の合計スコア: -40.0
# フレーム: 10, 行動: 3, 報酬: -5.0, 現在の合計スコア: -45.0
# フレーム: 11, 行動: 2, 報酬: -5.0, 現在の合計スコア: -50.0
# フレーム: 12, 行動: 2, 報酬: -5.0, 現在の合計スコア: -55.0
# フレーム: 13, 行動: 3, 報酬: -5.0, 現在の合計スコア: -60.0
# フレーム: 14, 行動: 3, 報酬: -5.0, 現在の合計スコア: -65.0
# フレーム: 15, 行動: 1, 報酬: -5.0, 現在の合計スコア: -70.0
# フレーム: 16, 行動: 0, 報酬: -5.0, 現在の合計スコア: -75.0
# フレーム: 17, 行動: 0, 報酬: -5.0, 現在の合計スコア: -80.0
# フレーム: 18, 行動: 1, 報酬: -5.0, 現在の合計スコア: -85.0
# フレーム: 19, 行動: 0, 報酬: -5.0, 現在の合計スコア: -90.0
# フレーム: 20, 行動: 0, 報酬: -5.0, 現在の合計スコア: -95.0
# フレーム: 21, 行動: 0, 報酬: -5.0, 現在の合計スコア: -100.0
# フレーム: 22, 行動: 0, 報酬: -5.0, 現在の合計スコア: -105.0
# フレーム: 23, 行動: 1, 報酬: -5.0, 現在の合計スコア: -110.0
# フレーム: 25, 行動: 1, 報酬: -5.0, 現在の合計スコア: -115.0
# フレーム: 26, 行動: 0, 報酬: -5.0, 現在の合計スコア: -120.0
# フレーム: 27, 行動: 0, 報酬: -5.0, 現在の合計スコア: -125.0
# フレーム: 28, 行動: 0, 報酬: -5.0, 現在の合計スコア: -130.0
# フレーム: 29, 行動: 0, 報酬: -5.0, 現在の合計スコア: -135.0
# フレーム: 30, 行動: 0, 報酬: -5.0, 現在の合計スコア: -140.0
# フレーム: 31, 行動: 0, 報酬: -5.0, 現在の合計スコア: -145.0
# フレーム: 32, 行動: 2, 報酬: -5.0, 現在の合計スコア: -150.0
# フレーム: 33, 行動: 2, 報酬: -5.0, 現在の合計スコア: -155.0
# フレーム: 35, 行動: 3, 報酬: -5.0, 現在の合計スコア: -160.0
# フレーム: 36, 行動: 0, 報酬: -5.0, 現在の合計スコア: -165.0
# フレーム: 37, 行動: 0, 報酬: -5.0, 現在の合計スコア: -170.0
# フレーム: 38, 行動: 0, 報酬: -5.0, 現在の合計スコア: -175.0
# フレーム: 39, 行動: 3, 報酬: -5.0, 現在の合計スコア: -180.0
# フレーム: 41, 行動: 3, 報酬: -5.0, 現在の合計スコア: -185.0
# フレーム: 42, 行動: 2, 報酬: -5.0, 現在の合計スコア: -190.0
# フレーム: 43, 行動: 1, 報酬: -5.0, 現在の合計スコア: -195.0
# フレーム: 44, 行動: 0, 報酬: -5.0, 現在の合計スコア: -200.0
# フレーム: 45, 行動: 2, 報酬: -5.0, 現在の合計スコア: -205.0
# フレーム: 46, 行動: 2, 報酬: -5.0, 現在の合計スコア: -210.0
# フレーム: 48, 行動: 1, 報酬: -5.0, 現在の合計スコア: -215.0
# フレーム: 49, 行動: 3, 報酬: -5.0, 現在の合計スコア: -220.0
# フレーム: 50, 行動: 1, 報酬: -5.0, 現在の合計スコア: -225.0
# フレーム: 51, 行動: 0, 報酬: -5.0, 現在の合計スコア: -230.0
# フレーム: 52, 行動: 1, 報酬: -5.0, 現在の合計スコア: -235.0
# フレーム: 53, 行動: 1, 報酬: -5.0, 現在の合計スコア: -240.0
# フレーム: 54, 行動: 3, 報酬: -5.0, 現在の合計スコア: -245.0
# フレーム: 55, 行動: 2, 報酬: -5.0, 現在の合計スコア: -250.0
# フレーム: 56, 行動: 3, 報酬: -5.0, 現在の合計スコア: -255.0
# フレーム: 57, 行動: 3, 報酬: -5.0, 現在の合計スコア: -260.0
# フレーム: 58, 行動: 3, 報酬: -5.0, 現在の合計スコア: -265.0
# フレーム: 59, 行動: 0, 報酬: -5.0, 現在の合計スコア: -270.0
# フレーム: 60, 行動: 3, 報酬: -5.0, 現在の合計スコア: -275.0
# フレーム: 61, 行動: 0, 報酬: -5.0, 現在の合計スコア: -280.0
# フレーム: 63, 行動: 1, 報酬: -5.0, 現在の合計スコア: -285.0
# フレーム: 65, 行動: 2, 報酬: -5.0, 現在の合計スコア: -290.0
# フレーム: 66, 行動: 3, 報酬: -5.0, 現在の合計スコア: -295.0
# フレーム: 67, 行動: 2, 報酬: -5.0, 現在の合計スコア: -300.0
# フレーム: 68, 行動: 1, 報酬: -5.0, 現在の合計スコア: -305.0
# フレーム: 69, 行動: 1, 報酬: -5.0, 現在の合計スコア: -310.0
# フレーム: 71, 行動: 2, 報酬: -5.0, 現在の合計スコア: -315.0
# フレーム: 72, 行動: 1, 報酬: -5.0, 現在の合計スコア: -320.0
# フレーム: 79, 行動: 1, 報酬: 60.0, 現在の合計スコア: -260.0
# フレーム: 81, 行動: 3, 報酬: 100.0, 現在の合計スコア: -160.0
# フレーム: 82, 行動: 3, 報酬: -5.0, 現在の合計スコア: -165.0
# フレーム: 89, 行動: 2, 報酬: 60.0, 現在の合計スコア: -105.0
# フレーム: 90, 行動: 3, 報酬: -5.0, 現在の合計スコア: -110.0
# フレーム: 91, 行動: 3, 報酬: -5.0, 現在の合計スコア: -115.0
# フレーム: 92, 行動: 1, 報酬: -5.0, 現在の合計スコア: -120.0
# フレーム: 93, 行動: 0, 報酬: -5.0, 現在の合計スコア: -125.0
# フレーム: 94, 行動: 2, 報酬: -5.0, 現在の合計スコア: -130.0
# フレーム: 95, 行動: 2, 報酬: -5.0, 現在の合計スコア: -135.0
# フレーム: 107, 行動: 3, 報酬: -50.0, 現在の合計スコア: -185.0
# フレーム: 109, 行動: 2, 報酬: 60.0, 現在の合計スコア: -125.0
# フレーム: 110, 行動: 2, 報酬: -5.0, 現在の合計スコア: -130.0
# フレーム: 111, 行動: 2, 報酬: -5.0, 現在の合計スコア: -135.0
# フレーム: 114, 行動: 1, 報酬: 40.0, 現在の合計スコア: -95.0
# フレーム: 115, 行動: 0, 報酬: -5.0, 現在の合計スコア: -100.0
# フレーム: 116, 行動: 0, 報酬: -5.0, 現在の合計スコア: -105.0
# フレーム: 117, 行動: 1, 報酬: -5.0, 現在の合計スコア: -110.0
# フレーム: 118, 行動: 2, 報酬: -5.0, 現在の合計スコア: -115.0
# フレーム: 120, 行動: 3, 報酬: -5.0, 現在の合計スコア: -120.0
# フレーム: 121, 行動: 1, 報酬: -5.0, 現在の合計スコア: -125.0
# フレーム: 126, 行動: 1, 報酬: 100.0, 現在の合計スコア: -25.0
# フレーム: 127, 行動: 3, 報酬: -5.0, 現在の合計スコア: -30.0
# フレーム: 129, 行動: 0, 報酬: 40.0, 現在の合計スコア: 10.0
# フレーム: 130, 行動: 2, 報酬: -5.0, 現在の合計スコア: 5.0
# フレーム: 131, 行動: 3, 報酬: -5.0, 現在の合計スコア: 0.0
# フレーム: 132, 行動: 1, 報酬: -5.0, 現在の合計スコア: -5.0
# フレーム: 136, 行動: 3, 報酬: 100.0, 現在の合計スコア: 95.0
# フレーム: 137, 行動: 3, 報酬: -5.0, 現在の合計スコア: 90.0
# フレーム: 142, 行動: 3, 報酬: 100.0, 現在の合計スコア: 190.0
# フレーム: 143, 行動: 0, 報酬: -5.0, 現在の合計スコア: 185.0
# フレーム: 145, 行動: 2, 報酬: -5.0, 現在の合計スコア: 180.0
# フレーム: 146, 行動: 0, 報酬: -5.0, 現在の合計スコア: 175.0
# フレーム: 147, 行動: 0, 報酬: -5.0, 現在の合計スコア: 170.0
# フレーム: 148, 行動: 0, 報酬: 40.0, 現在の合計スコア: 210.0
# フレーム: 149, 行動: 2, 報酬: -5.0, 現在の合計スコア: 205.0
# フレーム: 150, 行動: 2, 報酬: -5.0, 現在の合計スコア: 200.0
# フレーム: 151, 行動: 2, 報酬: -5.0, 現在の合計スコア: 195.0
# フレーム: 152, 行動: 0, 報酬: -5.0, 現在の合計スコア: 190.0
# フレーム: 153, 行動: 1, 報酬: -5.0, 現在の合計スコア: 185.0
# フレーム: 154, 行動: 0, 報酬: -5.0, 現在の合計スコア: 180.0
# フレーム: 155, 行動: 3, 報酬: -5.0, 現在の合計スコア: 175.0
# フレーム: 156, 行動: 2, 報酬: -5.0, 現在の合計スコア: 170.0
# フレーム: 157, 行動: 1, 報酬: -5.0, 現在の合計スコア: 165.0
# フレーム: 158, 行動: 0, 報酬: -5.0, 現在の合計スコア: 160.0
# フレーム: 159, 行動: 2, 報酬: -5.0, 現在の合計スコア: 155.0
# フレーム: 160, 行動: 1, 報酬: -5.0, 現在の合計スコア: 150.0
# フレーム: 161, 行動: 3, 報酬: -5.0, 現在の合計スコア: 145.0
# フレーム: 162, 行動: 2, 報酬: -5.0, 現在の合計スコア: 140.0
# フレーム: 163, 行動: 3, 報酬: 40.0, 現在の合計スコア: 180.0
# フレーム: 165, 行動: 0, 報酬: -5.0, 現在の合計スコア: 175.0
# フレーム: 166, 行動: 3, 報酬: -5.0, 現在の合計スコア: 170.0
# フレーム: 173, 行動: 1, 報酬: 100.0, 現在の合計スコア: 270.0
# フレーム: 177, 行動: 0, 報酬: 100.0, 現在の合計スコア: 370.0
# フレーム: 178, 行動: 3, 報酬: 40.0, 現在の合計スコア: 410.0
# フレーム: 179, 行動: 2, 報酬: -5.0, 現在の合計スコア: 405.0
# フレーム: 182, 行動: 1, 報酬: -5.0, 現在の合計スコア: 400.0
# フレーム: 183, 行動: 0, 報酬: -5.0, 現在の合計スコア: 395.0
# フレーム: 184, 行動: 2, 報酬: -5.0, 現在の合計スコア: 390.0
# フレーム: 185, 行動: 2, 報酬: -5.0, 現在の合計スコア: 385.0
# フレーム: 186, 行動: 1, 報酬: -5.0, 現在の合計スコア: 380.0
# フレーム: 187, 行動: 3, 報酬: -5.0, 現在の合計スコア: 375.0
# フレーム: 188, 行動: 2, 報酬: 40.0, 現在の合計スコア: 415.0
# フレーム: 191, 行動: 1, 報酬: -5.0, 現在の合計スコア: 410.0
# フレーム: 201, 行動: 0, 報酬: 40.0, 現在の合計スコア: 450.0
# フレーム: 207, 行動: 4, 報酬: -50.0, 現在の合計スコア: 400.0
# フレーム: 208, 行動: 2, 報酬: 100.0, 現在の合計スコア: 500.0
# フレーム: 215, 行動: 1, 報酬: 40.0, 現在の合計スコア: 540.0
# フレーム: 220, 行動: 3, 報酬: 40.0, 現在の合計スコア: 580.0
# フレーム: 221, 行動: 1, 報酬: -5.0, 現在の合計スコア: 575.0
# フレーム: 222, 行動: 3, 報酬: -5.0, 現在の合計スコア: 570.0
# フレーム: 224, 行動: 3, 報酬: -5.0, 現在の合計スコア: 565.0
# フレーム: 225, 行動: 2, 報酬: -5.0, 現在の合計スコア: 560.0
# フレーム: 226, 行動: 2, 報酬: -5.0, 現在の合計スコア: 555.0
# フレーム: 227, 行動: 0, 報酬: -5.0, 現在の合計スコア: 550.0
# フレーム: 236, 行動: 1, 報酬: 40.0, 現在の合計スコア: 590.0
# フレーム: 237, 行動: 1, 報酬: -5.0, 現在の合計スコア: 585.0
# フレーム: 239, 行動: 3, 報酬: -5.0, 現在の合計スコア: 580.0
# フレーム: 241, 行動: 0, 報酬: -5.0, 現在の合計スコア: 575.0
# フレーム: 242, 行動: 3, 報酬: -5.0, 現在の合計スコア: 570.0
# フレーム: 244, 行動: 3, 報酬: 40.0, 現在の合計スコア: 610.0
# フレーム: 245, 行動: 1, 報酬: -5.0, 現在の合計スコア: 605.0
# フレーム: 246, 行動: 2, 報酬: -5.0, 現在の合計スコア: 600.0
# フレーム: 248, 行動: 1, 報酬: 40.0, 現在の合計スコア: 640.0
# フレーム: 249, 行動: 3, 報酬: -5.0, 現在の合計スコア: 635.0
# フレーム: 250, 行動: 2, 報酬: -5.0, 現在の合計スコア: 630.0
# フレーム: 252, 行動: 1, 報酬: -5.0, 現在の合計スコア: 625.0
# フレーム: 259, 行動: 3, 報酬: 60.0, 現在の合計スコア: 685.0
# フレーム: 262, 行動: 0, 報酬: 100.0, 現在の合計スコア: 785.0
# フレーム: 265, 行動: 2, 報酬: -5.0, 現在の合計スコア: 780.0
# フレーム: 266, 行動: 1, 報酬: -5.0, 現在の合計スコア: 775.0
# フレーム: 273, 行動: 1, 報酬: 100.0, 現在の合計スコア: 875.0
# フレーム: 274, 行動: 3, 報酬: -5.0, 現在の合計スコア: 870.0
# フレーム: 275, 行動: 2, 報酬: -5.0, 現在の合計スコア: 865.0
# フレーム: 276, 行動: 2, 報酬: -5.0, 現在の合計スコア: 860.0
# フレーム: 277, 行動: 0, 報酬: -5.0, 現在の合計スコア: 855.0
# フレーム: 284, 行動: 2, 報酬: 60.0, 現在の合計スコア: 915.0
# フレーム: 285, 行動: 0, 報酬: 60.0, 現在の合計スコア: 975.0
# フレーム: 287, 行動: 1, 報酬: -5.0, 現在の合計スコア: 970.0
# フレーム: 297, 行動: 1, 報酬: -50.0, 現在の合計スコア: 920.0
# フレーム: 302, 行動: 3, 報酬: -50.0, 現在の合計スコア: 870.0
# フレーム: 307, 行動: 1, 報酬: -55.0, 現在の合計スコア: 815.0
# フレーム: 311, 行動: 2, 報酬: 100.0, 現在の合計スコア: 915.0
# フレーム: 312, 行動: 0, 報酬: -5.0, 現在の合計スコア: 910.0
# フレーム: 313, 行動: 2, 報酬: 40.0, 現在の合計スコア: 950.0
# フレーム: 314, 行動: 1, 報酬: -5.0, 現在の合計スコア: 945.0
# フレーム: 315, 行動: 0, 報酬: -5.0, 現在の合計スコア: 940.0
# フレーム: 316, 行動: 1, 報酬: -5.0, 現在の合計スコア: 935.0
# フレーム: 320, 行動: 2, 報酬: 60.0, 現在の合計スコア: 995.0
# フレーム: 321, 行動: 3, 報酬: -5.0, 現在の合計スコア: 990.0
# フレーム: 332, 行動: 2, 報酬: -50.0, 現在の合計スコア: 940.0
# フレーム: 337, 行動: 4, 報酬: -50.0, 現在の合計スコア: 890.0
# フレーム: 347, 行動: 4, 報酬: -50.0, 現在の合計スコア: 840.0
# フレーム: 351, 行動: 3, 報酬: 40.0, 現在の合計スコア: 880.0
# フレーム: 353, 行動: 1, 報酬: 100.0, 現在の合計スコア: 980.0
# フレーム: 355, 行動: 0, 報酬: 60.0, 現在の合計スコア: 1040.0
# フレーム: 356, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1035.0
# フレーム: 358, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1030.0
# フレーム: 359, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1025.0
# フレーム: 360, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1020.0
# フレーム: 362, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1015.0
# フレーム: 367, 行動: 2, 報酬: 100.0, 現在の合計スコア: 1115.0
# フレーム: 377, 行動: 0, 報酬: -50.0, 現在の合計スコア: 1065.0
# フレーム: 382, 行動: 0, 報酬: 50.0, 現在の合計スコア: 1115.0
# フレーム: 384, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1110.0
# フレーム: 386, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1105.0
# フレーム: 389, 行動: 0, 報酬: 40.0, 現在の合計スコア: 1145.0
# フレーム: 390, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1140.0
# フレーム: 391, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1135.0
# フレーム: 392, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1130.0
# フレーム: 396, 行動: 3, 報酬: 100.0, 現在の合計スコア: 1230.0
# フレーム: 397, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1225.0
# フレーム: 398, 行動: 2, 報酬: 40.0, 現在の合計スコア: 1265.0
# フレーム: 399, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1260.0
# フレーム: 402, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1255.0
# フレーム: 403, 行動: 1, 報酬: 40.0, 現在の合計スコア: 1295.0
# フレーム: 404, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1290.0
# フレーム: 405, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1285.0
# フレーム: 407, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1280.0
# フレーム: 409, 行動: 1, 報酬: 40.0, 現在の合計スコア: 1320.0
# フレーム: 412, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1315.0
# フレーム: 418, 行動: 2, 報酬: 100.0, 現在の合計スコア: 1415.0
# フレーム: 419, 行動: 2, 報酬: 40.0, 現在の合計スコア: 1455.0
# フレーム: 420, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1450.0
# フレーム: 421, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1445.0
# フレーム: 422, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1440.0
# フレーム: 423, 行動: 1, 報酬: 40.0, 現在の合計スコア: 1480.0
# フレーム: 424, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1475.0
# フレーム: 426, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1470.0
# フレーム: 427, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1465.0
# フレーム: 428, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1460.0
# フレーム: 429, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1455.0
# フレーム: 430, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1450.0
# フレーム: 431, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1445.0
# フレーム: 433, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1440.0
# フレーム: 434, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1435.0
# フレーム: 435, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1430.0
# フレーム: 436, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1425.0
# フレーム: 437, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1420.0
# フレーム: 440, 行動: 0, 報酬: 60.0, 現在の合計スコア: 1480.0
# フレーム: 441, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1475.0
# フレーム: 442, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1470.0
# フレーム: 443, 行動: 3, 報酬: 40.0, 現在の合計スコア: 1510.0
# フレーム: 444, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1505.0
# フレーム: 445, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1500.0
# フレーム: 446, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1495.0
# フレーム: 447, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1490.0
# フレーム: 449, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1485.0
# フレーム: 450, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1480.0
# フレーム: 451, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1475.0
# フレーム: 452, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1470.0
# フレーム: 455, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1465.0
# フレーム: 456, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1460.0
# フレーム: 457, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1455.0
# フレーム: 462, 行動: 3, 報酬: 100.0, 現在の合計スコア: 1555.0
# フレーム: 464, 行動: 0, 報酬: 40.0, 現在の合計スコア: 1595.0
# フレーム: 465, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1590.0
# フレーム: 466, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1585.0
# フレーム: 467, 行動: 1, 報酬: -5.0, 現在の合計スコア: 1580.0
# フレーム: 468, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1575.0
# フレーム: 469, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1570.0
# フレーム: 471, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1565.0
# フレーム: 472, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1560.0
# フレーム: 478, 行動: 0, 報酬: 100.0, 現在の合計スコア: 1660.0
# フレーム: 481, 行動: 2, 報酬: 100.0, 現在の合計スコア: 1760.0
# フレーム: 482, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1755.0
# フレーム: 487, 行動: 1, 報酬: 100.0, 現在の合計スコア: 1855.0
# フレーム: 488, 行動: 1, 報酬: 40.0, 現在の合計スコア: 1895.0
# フレーム: 489, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1890.0
# フレーム: 490, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1885.0
# フレーム: 491, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1880.0
# フレーム: 492, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1875.0
# フレーム: 493, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1870.0
# フレーム: 494, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1865.0
# フレーム: 496, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1860.0
# フレーム: 497, 行動: 0, 報酬: -5.0, 現在の合計スコア: 1855.0
# フレーム: 499, 行動: 3, 報酬: -5.0, 現在の合計スコア: 1850.0
# フレーム: 500, 行動: 2, 報酬: -5.0, 現在の合計スコア: 1845.0
#
# --- エピソード終了 ---
# 合計フレーム: 500
# 最終スコア: 1845.0
# --- テスト終了 ---

# %% [markdown]
# ## 학습화면 가시화

# %% [markdown]
# ## 학습화면 예시

# %%
# --- 0. ライブラリのインストール ---
# !pip install gymnasium pygame numpy "stable-baselines3[extra]" tensorboard imageio imageio-ffmpeg

# --- 1. ライブラリのインポート ---
import os
import gymnasium as gym
from gymnasium import spaces
import pygame
import numpy as np
import imageio
from IPython.display import Video, display

from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack, SubprocVecEnv
from gymnasium.wrappers import ResizeObservation, ReshapeObservation

import matplotlib.pyplot as plt
from stable_baselines3.common.callbacks import BaseCallback, CallbackList, EvalCallback
import torch

# GPU最適化設定
torch.backends.cudnn.benchmark = True

# --- 2. 強化学習ゲーム環境クラスの定義 ---
class RhythmGameEnv(gym.Env):
    """
    強化学習エージェントのための動的リズムゲーム環境。
    RL報酬と実際のゲームスコアを分離して計算します。
    """
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 30}

    def __init__(self, density='medium', render_mode=None):
        super().__init__()
        self.density = density
        self.render_mode = render_mode
        self.screen_width, self.screen_height = 300, 400
        self.num_lanes = 4
        self.note_width, self.note_height, self.note_speed = 50, 20, 5
        self.judgment_line_y = self.screen_height - 50
        
        self.judgments = {
            'perfect': {'range': 5,  'reward': 10000},
            'good':    {'range': 10, 'reward': 6000},
            'ok':      {'range': 20, 'reward': 4000},
        }
        self.miss_penalty = -10
        self.wrong_input_penalty = -5

        self.density_settings = {'low': 200, 'medium': 150, 'high': 80}
        self.min_spacing_frames = self.density_settings[self.density]
        self.action_space = spaces.Discrete(5)
        self.observation_space = spaces.Box(low=0, high=255, shape=(self.screen_height, self.screen_width, 1), dtype=np.uint8)
        
        self.screen = None
        self.clock = None
        if self.render_mode == "human":
            pygame.init()
            pygame.display.set_caption("Rhythm Game RL Environment")
            self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
            self.clock = pygame.time.Clock()

    def _generate_notes(self):
        notes = []
        for frame in range(0, 500, self.min_spacing_frames):
            if self.np_random.random() < 0.7:
                lane = self.np_random.integers(0, self.num_lanes)
                notes.append([lane, -self.note_height / 2 - frame * self.note_speed])
        return notes

    def _calculate_max_score(self):
        return len(self.notes) * self.judgments['perfect']['reward']

    def _get_obs(self):
        surface = pygame.Surface((self.screen_width, self.screen_height))
        surface.fill((255, 255, 255))
        lane_width = self.screen_width / self.num_lanes
        for i in range(1, self.num_lanes):
            pygame.draw.line(surface, (200, 200, 200), (i * lane_width, 0), (i * lane_width, self.screen_height), 1)
        for note in self.notes:
            lane, y_pos = note
            if 0 <= y_pos <= self.screen_height:
                x_pos = (lane + 0.5) * lane_width
                rect = pygame.Rect(x_pos - self.note_width / 2, y_pos - self.note_height / 2, self.note_width, self.note_height)
                pygame.draw.rect(surface, (0, 0, 0), rect)
        obs = pygame.surfarray.array3d(surface)
        obs = np.transpose(obs, (1, 0, 2))
        return np.mean(obs, axis=2, keepdims=True, dtype=np.uint8)

    def _get_info(self):
        return {
            "rl_score": self.total_rl_score, 
            "game_score": self.total_game_score,
            "max_score": self.max_score
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.notes = self._generate_notes()
        self.max_score = self._calculate_max_score()
        self.total_rl_score = 0
        self.total_game_score = 0
        self.current_frame = 0
        return self._get_obs(), self._get_info()

    def step(self, action):
        rl_reward = 0
        game_score_delta = 0
        done = False
        
        for note in self.notes: 
            note[1] += self.note_speed
        action_taken = action < self.num_lanes
        note_processed = False
        
        for note in self.notes[:]:
            lane, y_pos = note
            diff = abs(y_pos - self.judgment_line_y)
            if diff <= self.judgments['ok']['range']:
                if action_taken and action == lane:
                    if diff <= self.judgments['perfect']['range']:
                        score = self.judgments['perfect']['reward']
                    elif diff <= self.judgments['good']['range']:
                        score = self.judgments['good']['reward']
                    else:
                        score = self.judgments['ok']['reward']
                    
                    rl_reward += score
                    game_score_delta += score
                    self.notes.remove(note)
                    note_processed = True
                    break

        if action_taken and not note_processed:
            rl_reward += self.wrong_input_penalty

        removed_notes = [n for n in self.notes if n[1] > self.judgment_line_y + self.judgments['ok']['range']]
        if removed_notes:
            rl_reward += self.miss_penalty * len(removed_notes)
            self.notes = [n for n in self.notes if n not in removed_notes]

        self.total_rl_score += rl_reward
        self.total_game_score += game_score_delta
        self.current_frame += 1
        
        if not self.notes and self.current_frame > 500:
            done = True
            
        return self._get_obs(), rl_reward, done, False, self._get_info()
    
    def render(self):
        obs = self._get_obs()
        obs_rgb = np.repeat(obs, 3, axis=2)
        surface = pygame.surfarray.make_surface(np.transpose(obs_rgb, (1, 0, 2)))
        pygame.draw.line(surface, (255, 0, 0), (0, self.judgment_line_y), (self.screen_width, self.judgment_line_y), 2)
        if self.render_mode == "human":
            if self.screen is None:
                pygame.init()
                self.screen = pygame.display.set_mode((self.screen_width, self.screen_height))
            self.screen.blit(surface, (0, 0))
            pygame.event.pump()
            pygame.display.flip()
            if self.clock is None:
                self.clock = pygame.time.Clock()
            self.clock.tick(self.metadata["render_fps"])
            return None
        elif self.render_mode == "rgb_array":
            return np.transpose(pygame.surfarray.array3d(surface), (1, 0, 2))
            
    def close(self):
        if self.screen is not None:
            pygame.quit()
            self.screen = None

# --- 2種類のコールバックを定義 ---
class TrainingRewardLogger(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.t, self.rew = [], []

    def _on_step(self) -> bool:
        infos = self.locals.get("infos", None)
        if infos:
            for info in infos:
                ep = info.get("episode")
                if ep is not None:
                    self.t.append(self.num_timesteps)
                    self.rew.append(ep["r"])
        return True

EVAL_SEED_BASE = 2025

class EvalWithAccuracy(EvalCallback):
    def __init__(self, eval_env, *args, n_eval_episodes=5, **kwargs):
        super().__init__(eval_env, *args, n_eval_episodes=n_eval_episodes, **kwargs)
        self.eval_steps, self.eval_acc = [], []

    def _on_step(self) -> bool:
        result = super()._on_step()
        if self.eval_freq > 0 and self.n_calls % self.eval_freq == 0:
            acc_list, gs_list = [], []
            for ep in range(self.n_eval_episodes):
                try:
                    obs, _ = self.eval_env.reset(seed=EVAL_SEED_BASE + ep)
                except Exception:
                    obs = self.eval_env.reset()
                dones = np.array([False])
                while not dones[0]:
                    action, _ = self.model.predict(obs, deterministic=True)
                    obs, rewards, dones, infos = self.eval_env.step(action)
                info = infos[0] if isinstance(infos, (list, tuple)) else infos
                gs, ms = info.get("game_score"), info.get("max_score")
                if gs is not None: gs_list.append(float(gs))
                if gs is not None and ms and ms > 0:
                    acc_list.append(100.0 * float(gs) / float(ms))
            if gs_list: self.logger.record("eval/mean_game_score", float(np.mean(gs_list)))
            if acc_list:
                mean_acc = float(np.mean(acc_list))
                self.logger.record("eval/accuracy_pct", mean_acc)
                self.eval_steps.append(self.num_timesteps)
                self.eval_acc.append(mean_acc)
        return result

# === メイン実行ブロック ===
if __name__ == '__main__':
    # --- 3. 学習環境の設定 ---
    models_dir, logdir = "models", "logs"
    os.makedirs(models_dir, exist_ok=True)
    os.makedirs(logdir, exist_ok=True)
    DENSITY = 'high'
    ALGORITHM = 'PPO'

    # --- リソース活用及びハイパーパラメータ設定 ---
    N_ENVS = 16
    RESIZED_SHAPE = (100, 75) 
    TOTAL_TIMESTEPS = 3_500_000
    N_STEPS = 2048
    BATCH_SIZE = 4096
    N_EPOCHS = 4
    
    # [修正] 各ロールアウトごとに評価するには、`eval_freq`を`N_STEPS`に設定する必要があります。
    # コールバックは1ロールアウトあたりn_steps(2048)回呼び出されるため、この値に設定する必要があり、
    # 1ロールアウト(16*2048=32768タイムステップ)ごとに評価が実行されます。
    EVAL_FREQ = N_STEPS

    # --- 4. 環境の生成とラッピング（並列化） ---
    def make_env(rank: int, seed_base: int = 42):
        def _thunk():
            env = RhythmGameEnv(density=DENSITY, render_mode=None)
            env = Monitor(env)
            env = ResizeObservation(env, shape=RESIZED_SHAPE)
            env = ReshapeObservation(env, shape=(RESIZED_SHAPE[0], RESIZED_SHAPE[1], 1))
            env.reset(seed=seed_base + rank)
            return env
        return _thunk

    env = SubprocVecEnv([make_env(i) for i in range(N_ENVS)])
    env = VecFrameStack(env, n_stack=4, channels_order='last')
    
    eval_env = SubprocVecEnv([make_env(1000 + i) for i in range(2)])
    eval_env = VecFrameStack(eval_env, n_stack=4, channels_order='last')

    # --- 5. モデルとコールバックの定義 ---
    model = PPO(
        'CnnPolicy',
        env,
        learning_rate=1e-4, # デフォルト値。チューニング時にコメントを解除して調整
        verbose=0,
        tensorboard_log=logdir,
        device='cuda',
        n_steps=N_STEPS,
        batch_size=BATCH_SIZE,
        n_epochs=N_EPOCHS,
        gae_lambda=0.95,
        gamma=0.99,
    )

    train_rew_cb = TrainingRewardLogger()
    eval_callback = EvalWithAccuracy(
        eval_env,
        best_model_save_path=os.path.join(models_dir, f'best_model_{ALGORITHM}_{DENSITY}'),
        log_path=logdir,
        eval_freq=EVAL_FREQ,
        deterministic=True,
        render=False,
        n_eval_episodes=5,
    )
    callbacks = CallbackList([train_rew_cb, eval_callback])

    # --- 6. モデルの学習 ---
    print(f"--- {ALGORITHM} モデルの学習開始 (n_envs={N_ENVS}, n_steps={N_STEPS}, batch_size={BATCH_SIZE}, Timesteps={TOTAL_TIMESTEPS}) ---")
    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=callbacks, tb_log_name=f"{ALGORITHM}_{DENSITY}")
    env.close()
    eval_env.close()
    print("--- 学習完了 ---")

    # --- 7. 結果の可視化 ---
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_rew_cb.t, train_rew_cb.rew)
    plt.xlabel("Timesteps")
    plt.ylabel("Episode Reward")
    plt.title("Training: Episode Reward over Timesteps")

    plt.subplot(1, 2, 2)
    plt.plot(eval_callback.eval_steps, eval_callback.eval_acc, marker="o")
    plt.xlabel("Timesteps")
    plt.ylabel("Accuracy (%)")
    plt.title(f"Evaluation Accuracy")
    
    # [修正] X軸の範囲を0から全学習時間まで強制的に設定し、すべての評価点を確認
    plt.xlim(0, TOTAL_TIMESTEPS)

    plt.tight_layout()
    plt.show()

    print("\n--- TensorBoardで学習過程を確認する方法 ---")
    print(f"%load_ext tensorboard\n%tensorboard --logdir {logdir}")

    # --- 8. 最高性能モデルの可視化 ---
    print("\n--- 最高性能モデルのプレイ動画録画開始 ---")
    
    viz_env_raw = RhythmGameEnv(density=DENSITY, render_mode='rgb_array')
    viz_env_wrapped = ResizeObservation(viz_env_raw, shape=RESIZED_SHAPE)
    viz_env_wrapped = ReshapeObservation(viz_env_wrapped, shape=(RESIZED_SHAPE[0], RESIZED_SHAPE[1], 1))
    viz_vec_env = DummyVecEnv([lambda: viz_env_wrapped])
    viz_vec_env = VecFrameStack(viz_vec_env, n_stack=4, channels_order='last')
    
    best_model_path = os.path.join(models_dir, f'best_model_{ALGORITHM}_{DENSITY}', 'best_model.zip')
    video_path = f"agent_play_{ALGORITHM}_{DENSITY}.mp4"
    frames = []

    try:
        loaded_model = PPO.load(best_model_path, device='cuda')
        print(f"最高性能モデルの読み込み成功: {best_model_path}")

        obs = viz_vec_env.reset()
        dones = np.array([False])
        
        while not np.all(dones):
            action, _ = loaded_model.predict(obs, deterministic=True)
            obs, rewards, dones, infos = viz_vec_env.step(action)
            frame = viz_vec_env.envs[0].render()
            if frame is not None:
                frames.append(frame)
        
        final_info = infos[0] if isinstance(infos, (list, tuple)) else infos
        final_game_score = final_info.get('game_score', 0)
        max_score = final_info.get('max_score', 0)
        score_percentage = (final_game_score / max_score) * 100 if max_score > 0 else 0.0

        viz_vec_env.close()
        print(f"--- 動画録画終了 ---")
        print(f"最高性能エージェントの最終スコア: {final_game_score:.0f} / {max_score:.0f} ({score_percentage:.2f}%)")
        
        print(f"プレイ動画を'{video_path}'ファイルとして保存します...")
        imageio.mimsave(video_path, [np.array(f) for f in frames], fps=30)
        print("保存完了。")
        # display(Video(video_path, embed=True, width=300)) # Jupyter環境で実行する際にコメントを解除
        
    except FileNotFoundError:
        print(f"エラー: 最高性能モデルファイルが見つかりません。 ({best_model_path})")
# Out:
# --- PPO モデルの学習開始 (n_envs=16, n_steps=2048, batch_size=4096, Timesteps=3500000) ---
# c:\venv_for_ipynb\venv_python_3.11\Lib\site-packages\stable_baselines3\common\callbacks.py:418: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.vec_transpose.VecTransposeImage object at 0x000001A8E80F2450> != <stable_baselines3.common.vec_env.vec_frame_stack.VecFrameStack object at 0x000001A8E942D1D0>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Eval num_timesteps=32768, episode_reward=2041.00 +/- 2909.66
# Episode length: 545.80 +/- 22.40
# New best mean reward!
# Eval num_timesteps=65536, episode_reward=8432.00 +/- 3932.92
# Episode length: 551.60 +/- 4.41
# New best mean reward!
# Eval num_timesteps=98304, episode_reward=2114.00 +/- 3851.60
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=131072, episode_reward=2161.00 +/- 2877.65
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=163840, episode_reward=2035.00 +/- 1579.20
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=196608, episode_reward=437.00 +/- 1640.13
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=229376, episode_reward=3749.00 +/- 4110.70
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=262144, episode_reward=2158.00 +/- 1658.18
# Episode length: 521.60 +/- 25.39
# Eval num_timesteps=294912, episode_reward=2962.00 +/- 4849.60
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=327680, episode_reward=2969.00 +/- 4137.25
# Episode length: 521.60 +/- 25.39
# Eval num_timesteps=360448, episode_reward=2116.00 +/- 5861.63
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=393216, episode_reward=5265.00 +/- 3603.84
# Episode length: 542.20 +/- 20.99
# Eval num_timesteps=425984, episode_reward=2039.00 +/- 4670.56
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=458752, episode_reward=3587.00 +/- 5447.10
# Episode length: 557.00 +/- 0.00
# Eval num_timesteps=491520, episode_reward=1286.00 +/- 2456.57
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=524288, episode_reward=2906.00 +/- 5360.55
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=557056, episode_reward=-2655.00 +/- 135.06
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=589824, episode_reward=1977.00 +/- 3006.16
# Episode length: 557.00 +/- 0.00
# Eval num_timesteps=622592, episode_reward=390.00 +/- 2997.39
# Episode length: 555.20 +/- 3.60
# Eval num_timesteps=655360, episode_reward=1251.00 +/- 4504.24
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=688128, episode_reward=6063.00 +/- 3934.50
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=720896, episode_reward=2918.00 +/- 5991.92
# Episode length: 531.00 +/- 24.71
# Eval num_timesteps=753664, episode_reward=5317.00 +/- 2449.33
# Episode length: 531.00 +/- 24.71
# Eval num_timesteps=786432, episode_reward=3645.00 +/- 4789.80
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=819200, episode_reward=2091.00 +/- 1547.45
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=851968, episode_reward=-316.00 +/- 1947.25
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=884736, episode_reward=-358.00 +/- 2016.81
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=917504, episode_reward=2849.00 +/- 2035.74
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=950272, episode_reward=450.00 +/- 3890.00
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=983040, episode_reward=497.00 +/- 2949.06
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=1015808, episode_reward=2913.00 +/- 4049.65
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=1048576, episode_reward=506.00 +/- 3848.39
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=1081344, episode_reward=2795.00 +/- 4118.45
# Episode length: 555.20 +/- 3.60
# Eval num_timesteps=1114112, episode_reward=1979.00 +/- 2994.96
# Episode length: 557.00 +/- 0.00
# Eval num_timesteps=1146880, episode_reward=3755.00 +/- 3152.49
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=1179648, episode_reward=3611.00 +/- 3199.36
# Episode length: 553.40 +/- 4.41
# Eval num_timesteps=1212416, episode_reward=442.00 +/- 1636.66
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=1245184, episode_reward=1299.00 +/- 4338.01
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=1277952, episode_reward=543.00 +/- 3049.00
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=1310720, episode_reward=1290.00 +/- 2543.56
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=1343488, episode_reward=-1107.00 +/- 1998.43
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=1376256, episode_reward=5216.00 +/- 5089.70
# Episode length: 551.60 +/- 4.41
# Eval num_timesteps=1409024, episode_reward=3024.00 +/- 3991.96
# Episode length: 512.20 +/- 22.40
# Eval num_timesteps=1441792, episode_reward=1189.00 +/- 5084.96
# Episode length: 555.20 +/- 3.60
# Eval num_timesteps=1474560, episode_reward=557.00 +/- 1546.27
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=1507328, episode_reward=1979.00 +/- 3922.46
# Episode length: 557.00 +/- 0.00
# Eval num_timesteps=1540096, episode_reward=1988.00 +/- 3004.65
# Episode length: 555.20 +/- 3.60
# Eval num_timesteps=1572864, episode_reward=2051.00 +/- 3066.31
# Episode length: 542.20 +/- 20.99
# Eval num_timesteps=1605632, episode_reward=4457.00 +/- 4645.76
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=1638400, episode_reward=-316.00 +/- 1947.55
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=1671168, episode_reward=1986.00 +/- 4669.78
# Episode length: 555.20 +/- 3.60
# Eval num_timesteps=1703936, episode_reward=2842.00 +/- 5377.57
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=1736704, episode_reward=-1220.00 +/- 1965.78
# Episode length: 555.20 +/- 3.60
# Eval num_timesteps=1769472, episode_reward=5318.00 +/- 2470.53
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=1802240, episode_reward=1318.00 +/- 2452.35
# Episode length: 531.00 +/- 24.71
# Eval num_timesteps=1835008, episode_reward=5284.00 +/- 2438.63
# Episode length: 540.40 +/- 20.01
# Eval num_timesteps=1867776, episode_reward=3717.00 +/- 4039.49
# Episode length: 531.00 +/- 24.71
# Eval num_timesteps=1900544, episode_reward=2049.00 +/- 2989.37
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=1933312, episode_reward=7661.00 +/- 5992.73
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=1966080, episode_reward=3643.00 +/- 4066.17
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=1998848, episode_reward=2052.00 +/- 1597.89
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=2031616, episode_reward=1295.00 +/- 4414.75
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=2064384, episode_reward=-314.00 +/- 3270.76
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=2097152, episode_reward=2918.00 +/- 4052.62
# Episode length: 531.00 +/- 24.71
# Eval num_timesteps=2129920, episode_reward=499.00 +/- 3027.06
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=2162688, episode_reward=2116.00 +/- 1687.90
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=2195456, episode_reward=1288.00 +/- 2446.88
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=2228224, episode_reward=6068.00 +/- 3852.99
# Episode length: 542.20 +/- 20.99
# Eval num_timesteps=2260992, episode_reward=1412.00 +/- 2538.58
# Episode length: 512.20 +/- 22.40
# Eval num_timesteps=2293760, episode_reward=2960.00 +/- 7498.87
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=2326528, episode_reward=3646.00 +/- 4132.96
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=2359296, episode_reward=2855.00 +/- 5387.09
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=2392064, episode_reward=564.00 +/- 1707.69
# Episode length: 521.60 +/- 25.39
# Eval num_timesteps=2424832, episode_reward=547.00 +/- 3047.74
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=2457600, episode_reward=2065.00 +/- 4651.32
# Episode length: 542.20 +/- 20.99
# Eval num_timesteps=2490368, episode_reward=2840.00 +/- 1929.85
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=2523136, episode_reward=1356.00 +/- 4286.08
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=2555904, episode_reward=431.00 +/- 3105.34
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=2588672, episode_reward=1305.00 +/- 2539.60
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=2621440, episode_reward=1299.00 +/- 2626.49
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=2654208, episode_reward=2044.00 +/- 3056.64
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=2686976, episode_reward=-1169.00 +/- 2034.53
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=2719744, episode_reward=2153.00 +/- 3960.88
# Episode length: 523.40 +/- 27.43
# Eval num_timesteps=2752512, episode_reward=2039.00 +/- 4774.39
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=2785280, episode_reward=2048.00 +/- 2910.20
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=2818048, episode_reward=4457.00 +/- 5349.43
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=2850816, episode_reward=1246.00 +/- 2538.85
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=2883584, episode_reward=6826.00 +/- 5446.98
# Episode length: 551.60 +/- 4.41
# Eval num_timesteps=2916352, episode_reward=2851.00 +/- 3113.73
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=2949120, episode_reward=3010.00 +/- 3242.18
# Episode length: 512.20 +/- 22.40
# Eval num_timesteps=2981888, episode_reward=2104.00 +/- 2971.25
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=3014656, episode_reward=1236.00 +/- 2436.30
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=3047424, episode_reward=6075.00 +/- 3066.45
# Episode length: 540.40 +/- 20.01
# Eval num_timesteps=3080192, episode_reward=-316.00 +/- 1943.13
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=3112960, episode_reward=5374.00 +/- 3598.99
# Episode length: 521.60 +/- 25.39
# Eval num_timesteps=3145728, episode_reward=3648.00 +/- 3156.94
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=3178496, episode_reward=6065.00 +/- 2990.03
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=3211264, episode_reward=4402.00 +/- 8953.96
# Episode length: 553.40 +/- 4.41
# Eval num_timesteps=3244032, episode_reward=2899.00 +/- 1985.38
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=3276800, episode_reward=-1169.00 +/- 1921.08
# Episode length: 545.80 +/- 22.40
# Eval num_timesteps=3309568, episode_reward=-1042.00 +/- 1959.79
# Episode length: 521.60 +/- 25.39
# Eval num_timesteps=3342336, episode_reward=4519.00 +/- 4664.01
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=3375104, episode_reward=4515.00 +/- 3037.38
# Episode length: 532.80 +/- 26.17
# Eval num_timesteps=3407872, episode_reward=2044.00 +/- 6391.70
# Episode length: 544.00 +/- 21.78
# Eval num_timesteps=3440640, episode_reward=2784.00 +/- 4087.46
# Episode length: 557.00 +/- 0.00
# Eval num_timesteps=3473408, episode_reward=5307.00 +/- 2630.63
# Episode length: 534.60 +/- 27.43
# Eval num_timesteps=3506176, episode_reward=4498.00 +/- 7302.51
# Episode length: 534.60 +/- 27.43
# --- 学習完了 ---
# --- TensorBoardで学習過程を確認する方法 ---
# %load_ext tensorboard
# %tensorboard --logdir logs
#
# --- 最高性能モデルのプレイ動画録画開始 ---
# 最高性能モデルの読み込み成功: models\best_model_PPO_high\best_model.zip
# --- 動画録画終了 ---
# 最高性能エージェントの最終スコア: 12000 / 60000 (20.00%)
# プレイ動画を'agent_play_PPO_high.mp4'ファイルとして保存します...
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (300, 400) to (304, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# 保存完了。

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 10512), started 18:37:00 ago. (Use '!kill 10512' to kill it.)
#       <iframe id="tensorboard-frame-172355f3930e3a4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-172355f3930e3a4");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
